# %%
import sound_utils as utils
from scipy.io import wavfile
import numpy as np
import matplotlib.pyplot as plt
import simpleaudio as sa
import sounddevice as sd
from IPython.display import Audio
import librosa

duration = 2
sample_rate = 44100

t = np.linspace(0, duration, int(sample_rate * duration), endpoint=False)

# %%
# !pip install librosa

# %%
y1 = utils.generate_sine( 220, duration)
y2 = utils.generate_sine( 7000, duration)

audio = Audio(y1, rate=sample_rate)
display(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio = Audio(y2, rate=sample_rate)
display(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#plot two sine waves... y1,y2 for 0.01 sec.
utils.plot_2_sines(y1,y2,'Sine Wave 1', 'Sine Wave 2' ,0.01,t)

# %%
utils.plot_spectogram( y1, y2 , 'Spectorgam for Sine Wave 1', 'Spectorgam for Sine Wave 2' )
# Out:
# C:\Users\intel\miniforge3\envs\work_env\Lib\site-packages\matplotlib\axes\_axes.py:8089: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %%
audio_path = 'wav-files/scale_up.wav'
scale_up, sample_rate = librosa.load(audio_path, sr=None)
Audio(scale_up, rate=sample_rate)
# Out:
# C:\Users\intel\AppData\Local\Temp\ipykernel_1844\1900426901.py:2: UserWarning: PySoundFile failed. Trying audioread instead.
#   scale_up, sample_rate = librosa.load(audio_path, sr=None)
# C:\Users\intel\miniforge3\envs\work_env\Lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# File ~\miniforge3\envs\work_env\Lib\site-packages\librosa\core\audio.py:176, in load(path, sr, mono, offset, duration, dtype, res_type)
#     175 try:
# --> 176     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     178 except sf.SoundFileRuntimeError as exc:
#     179     # If soundfile failed, try audioread instead
#
# ...

# %%
audio_path = 'wav-files/scale_dn.wav'
scale_dn, sample_rate = librosa.load(audio_path, sr=None)
Audio(scale_dn, rate=sample_rate)

# %%
utils.plot_spectogram( scale_up, scale_dn, 'spectogram for scale UP', 'spectogram for scale Down', )

# %%
audio_path = 'wav-files/flute.wav'
flute, sample_rate = librosa.load(audio_path, sr=None)
Audio(flute, rate=sample_rate)

# %%
audio_path = 'wav-files/violin.wav'
violin, sample_rate = librosa.load(audio_path, sr=None)
Audio(violin, rate=sample_rate)

# %%
utils.plot_spectogram( flute, violin , 'Flute', 'Violin' )

# %%
how does real music looks like? load audio, show the signal..
